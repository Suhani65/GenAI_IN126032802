# %% [markdown]
# # 🚀 LangChain Deep Technical Implementation (Google Colab)
#
# ## 📌 Overview
# This notebook demonstrates a practical implementation of **LangChain**, a powerful framework for building applications powered by Large Language Models (LLMs).
#
# The goal of this notebook is to explore key LangChain components through working Python code, without relying on paid APIs.
#
# ---
#
# ## 🎯 Objectives
# - Understand core LangChain concepts
# - Implement modular LLM pipelines
# - Explore chaining, prompts, and tools
# - Simulate memory handling
# - Build a simple vector database using FAISS
#
# ---
#
# ## 🛠️ Technologies Used
# - Python
# - LangChain (latest modular version)
# - Hugging Face Transformers (free models)
# - FAISS (Vector Database)
#
# ---
#
# ## ⚙️ Key Components Covered
# - ✅ LLM (HuggingFace Pipeline)
# - ✅ Prompt Templates
# - ✅ Chains using LCEL (`|` operator)
# - ✅ Tool / Agent Logic (simulated)
# - ✅ Memory (simulated buffer)
# - ✅ Document Loader
# - ✅ Vector Store (FAISS)

# %%
# !pip install -U langchain langchain-community langchain-core transformers accelerate faiss-cpu sentence-transformers

# %%
from langchain_community.llms import HuggingFacePipeline
from transformers import pipeline

pipe = pipeline(
    "text-generation",
    model="distilgpt2",
    max_new_tokens=50
)

llm = HuggingFacePipeline(pipeline=pipe)

response = llm.invoke("Explain AI in simple terms")
print(response)

# %%
from langchain_core.prompts import PromptTemplate

prompt = PromptTemplate.from_template("Explain {topic} in simple terms")

formatted = prompt.format(topic="Machine Learning")
print(formatted)
# Out:
# Explain Machine Learning in simple terms

# %%
from langchain_core.output_parsers import StrOutputParser

chain = prompt | llm | StrOutputParser()

result = chain.invoke({"topic": "Artificial Intelligence"})
print(result)

# %%
history = []

# simulate conversation
history.append(("Hi", "Hello"))
history.append(("What is AI?", "AI is artificial intelligence"))

# print memory
for i, (inp, out) in enumerate(history):
    print(f"User: {inp}")
    print(f"AI: {out}")
    print("---")
# Out:
# User: Hi
# AI: Hello
# ---
# User: What is AI?
# AI: AI is artificial intelligence
# ---

# %%
from langchain_community.vectorstores import FAISS
from langchain_community.embeddings import HuggingFaceEmbeddings

embedding = HuggingFaceEmbeddings()

texts = ["LangChain is powerful", "AI is transforming the world"]

vectorstore = FAISS.from_texts(texts, embedding)

print("Vector DB created successfully!")
